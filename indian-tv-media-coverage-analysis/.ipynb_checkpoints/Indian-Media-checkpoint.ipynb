# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# Replace 'url_here' with the URL of the page containing the table
url = 'https://mattw.io/youtube-metadata/bulk?url=https%3A%2F%2Fwww.youtube.com%2Fplaylist%3Flist%3DPL3HhMTCWB-e_FA-VkkE_gn-JbOVWfklql&submit=true'

# Send a GET request to the URL
response = requests.get(url)

# Parse the HTML content of the page
soup = BeautifulSoup(response.content, 'html.parser')

# Find all tables on the page
tables = soup.find('#videosTable')

tables

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="dark" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="Quickly gather all the metadata about a video, playlist, or channel from the YouTube API. Reverse image search thumbnails, geolocate in google maps, and translate ISO country and language codes." name="description"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <link href="./img/icon.png" rel="icon"/>
# <title>MW Metadata Bulk</title>
# <link crossorigin="" href="//cdn.jsdelivr.net" rel="preconnect"/>
# <!-- Dependencies -->
# <link href="//cdn.datatables.net/1.11.3/css/dataTables.bootstrap5.min.css" rel="stylesheet"/>
# <link href="//cdn.jsdelivr.net/gh/highlightjs/cdn-release@11.3.1/build/styles/stackoverflow-dark.min.css" id="highlightjs-theme" rel="stylesheet"/>
# <link href="//cdn.jsdelivr.net/npm/bootstrap-dark-5@1.1.3/dist/css/bootstrap-nightshade.min.css" rel="stylesheet"/>
# <link href="//cdn.jsdelivr.net/npm/bootstrap-icons@1.5.0/font/bootstrap-icons.css" rel="stylesheet"/>
# <link href="./css/youtube-metadata.css?v=2023-09-18T03:53:27+00:00" rel="stylesheet">
# <script src="//code.jquery.com/jquery-3.6.0.min.js"></script>
# <script src="//cdn.datatables.net/1.11.3/js/jquery.dataTables.min.js"></script>
# <script src="//cdn.datatables.net/1.11.3/js/dataTables.bootstrap5.js"></script>
# <script src="//cdn.jsdelivr.net/gh/highlightjs/cdn-release@11.3.1/build/highlight.min.js"></script>
# <script src="//cdn.jsdelivr.net/npm/apexcharts@3.32.0/dist/apexcharts.min.js"></script>
# <script src="//cdn.jsdelivr.net/npm/bootstrap-dark-5@1.1.3/dist/js/darkmode.min.js"></script>
# <script src="//cdn.jsdelivr.net/npm/bootstrap@5.1.3/dist/js/bootstrap.bundle.min.js"></script>
# <script src="//cdn.jsdelivr.net/npm/bootstrap-multiselect@1.1.0/dist/js/bootstrap-multiselect.min.js"></script>
# <script src="//cdn.jsdelivr.net/npm/clipboard@2.0.8/dist/clipboard.min.js"></script>
# <script src="//cdn.jsdelivr.net/npm/file-saver@2.0.5/dist/FileSaver.min.js"></script>
# <script src="//cdn.jsdelivr.net/npm/jszip-utils@0.1.0/dist/jszip-utils.min.js"></script>
# <script src="//cdn.jsdelivr.net/npm/jszip@3.7.1/dist/jszip.min.js"></script>
# <script src="//cdn.jsdelivr.net/npm/moment@2.29.4/moment.min.js" type="text/javascript"></script>
# <script src="//cdn.jsdelivr.net/npm/xregexp@5.1.0/xregexp-all.js"></script>
# <script src="./js/randojs-2.0.0.js"></script>
# <!-- App -->
# <script src="./js/iso-639-translator.js?v=2023-09-18T03:53:27+00:00" type="text/javascript"></script>
# <script src="./js/iso-3166-translator.js?v=2023-09-18T03:53:27+00:00" type="text/javascript"></script>
# <script src="./js/bcp-47-translator.js?v=2023-09-18T03:53:27+00:00" type="text/javascript"></script>
# <script src="./js/yt-category-translator.js?v=2023-09-18T03:53:27+00:00" type="text/javascript"></script>
# <script src="./js/youtube-api-v3.js?v=2023-09-18T03:53:27+00:00" type="text/javascript"></script>
# <script src="./js/youtube-metadata-examples.js?v=2023-09-18T03:53:27+00:00" type="text/javascript"></script>
# <script src="./js/shared.js?v=2023-09-18T03:53:27+00:00" type="text/javascript"></script>
# <script src="./js/youtube-metadata-bulk.js?v=2023-09-18T03:53:27+00:00" type="text/javascript"></script>
# <!-- Analytics -->
# <script data-domain="mattw.io" defer="" src="https://plausible.io/js/plausible.js"></script>
# </link></head>
# <body>
# <nav class="navbar navbar-expand-lg navbar-light mb-15" style="border-bottom: 1px solid rgba(127,127,127,0.1);">
# <div class="container">
# <div class="navbar-brand">
# <img alt="" class="d-inline-block align-text-top" src="./img/icon.png"/>
# <span style="padding-left: .75rem;">MW Metadata Bulk</span>
# </div>
# <button aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-bs-target="#navbarSupportedContent" data-bs-toggle="collapse" type="button">
# <span class="navbar-toggler-icon"></span>
# </button>
# <div class="collapse navbar-collapse" id="navbarSupportedContent">
# <ul class="navbar-nav me-auto mb-2 mb-lg-0">
# <li class="nav-item">
# <a class="nav-link" href="./">Normal</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="./bulk">Bulk</a>
# </li>
# </ul>
# <form class="d-flex">
# <div class="form-check form-switch">
# <input checked="" class="form-check-input" id="darkMode" role="switch" type="checkbox"/>
# <label class="form-check-label" for="darkMode">Dark</label>
# </div>
# <script>
#                     const switchDarkMode = document.querySelector("#darkMode");
#                     switchDarkMode.onclick = function (e) {
#                         darkmode.toggleDarkMode();
#                     }
#                     window.addEventListener('DOMContentLoaded', () => {
#                         if (DarkMode.getColorScheme() === "dark") {
#                             console.log(1)
#                             switchDarkMode.setAttribute("checked", "checked");
#                         } else {
#                             console.log(2)
#                             switchDarkMode.removeAttribute("checked");
#                         }
#                     });
#                 </script>
# </form>
# </div>
# </div>
# </nav>
# <div class="container">
# <p>
#         MW Metadata bulk grabs details about multiple YouTube videos, a playlist's videos, or a channel's public videos.
#     </p>
# <p>
#         Submit a comma or whitespace separated list of multiple videos, playlists, or channels
#     </p>
# <div class="input-group mb-3">
# <input aria-describedby="submit" aria-label="https://www.youtube.com/channel/UCuAXFkgsw1L7xaCfnd5JJOw" autocomplete="off" class="form-control" id="value" placeholder="https://www.youtube.com/channel/UCuAXFkgsw1L7xaCfnd5JJOw" type="text"/>
# <button class="btn btn-primary loading disabled" id="submit" type="button">
# <span>Submit</span>
# <span class="countdown"></span>
# </button>
# </div>
# <div class="form-check">
# <input autocomplete="off" class="form-check-input" id="createdPlaylists" type="checkbox" value=""/>
# <label class="form-check-label" for="createdPlaylists">
#             Inspect videos in created playlists to find unlisted, private, and deleted videos (channels only)
#         </label>
# </div>
# </div>
# <div class="container mb-15" style="margin-top: 1.25%">
# <span>Accepted formats</span>
# <ul class="collapse show" id="formats" style="padding-top:7px">
# <li><span class="optional">https://www.</span>youtube.com/watch?v=<span class="orange">video_id</span></li>
# <li><span class="optional">https://</span>youtube.com/shorts/<span class="orange">video_id</span></li>
# <li><span class="optional">https://</span>youtu.be/<span class="orange">video_id</span></li>
# <li><span class="optional">https://www.</span>youtube.com/playlist?list=<span class="orange">playlist_id</span></li>
# <li><span class="optional">https://www.</span>youtube.com/channel/<span class="orange">channel_id</span></li>
# <li><span class="optional">https://www.</span>youtube.com/user/<span class="orange">username</span></li>
# <li><span class="optional">https://www.</span>youtube.com/@<span class="orange">channel_handle</span>
# <li><span class="optional">https://www.</span>youtube.com/c/<span class="orange">custom_url</span></li>
# <li><span class="optional">https://www.</span>youtube.com/<span class="orange">custom_url</span></li>
# <li>
#             Also accepts direct ids:
#             <span class="orange">video_id</span>,
#             <span class="orange">playlist_id</span>,
#             <span class="orange">channel_id</span>
# </li>
# </li></ul>
# </div>
# <div class="container mb-15">
# <h2><span class="export">Export &amp;</span> Share</h2>
# <p class="export">Save this result as a zip file or load from a previous export. Drag and drop supported.</p>
# <button class="btn btn-secondary export" id="export">
# <span class="spinner"><span class="spinner-border spinner-border-sm" role="status"></span></span>
# <span class="text"><i class="bi bi-download"></i>  Export</span>
# </button><span class="export"> </span>
# <button class="btn btn-secondary export" id="import" onclick="document.getElementById('importFileChooser').click()">
# <span class="spinner"><span class="spinner-border spinner-border-sm" role="status"></span></span>
# <span class="text"><i class="bi bi-upload"></i>  Import</span>
# <input hidden="" id="importFileChooser" type="file">
# </input></button>
# <div class="form-check export" style="margin:10px 0">
# <input autocomplete="off" class="form-check-input" id="includeThumbs" type="checkbox" value=""/>
# <label class="form-check-label" for="includeThumbs">
#             Include thumbnails on export (this may take a long time)
#             <span class="orange" id="thumbProgress"></span>
# </label>
# </div>
# <p class="export">Contains file(s)</p>
# <ul class="export">
# <li>about.txt - Metadata about this result.</li>
# <li>videos.json - Array of all raw video data.</li>
# <li>channels.json - Array of all raw channel data.</li>
# <li>playlists.json - Array of all raw playlist data.</li>
# <li>unavailable.json - Basic data for unavailable videos.</li>
# <li>✱.csv - Data from each table section below.</li>
# <li>thumbs/✱.png - Thumbs if available.</li>
# </ul>
# <p class="export"></p>
# <p>Share this result:</p>
# <div class="input-group" style="max-width: 226px;">
# <input aria-describedby="copy" autocomplete="off" class="form-control" id="shareLink" type="text"/>
# <button class="btn btn-primary clipboard" data-clipboard-target="#shareLink" type="button"><i class="bi bi-clipboard"></i></button>
# </div>
# <p style="margin-top: 10px">
# <a href="https://github.com/mattwright324/youtube-metadata/discussions/150" target="_blank">
#             What happened to export?
#         </a>
# </p>
# </div>
# <div class="container mb-15">
# <h2>Videos</h2>
# <p>
#         List of all videos, playlist videos, or channel public uploads.
#         Customize columns to show more or less data as needed.
#     </p>
# <div class="progress" style="margin-bottom:5px">
# <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="0" class="progress-bar" id="progressBar" role="progressbar" style="">
# <div class="label"></div>
# </div>
# </div>
# <div id="progressText" style="width: 100%;text-align: center;">Idle</div>
# <br/>
# <label for="column-options">Select column(s)</label>
# <select hidden="" id="column-options" multiple="multiple"></select>
# </div>
# <div class="container-fluid mb-15">
# <table class="table table-striped table-hover" id="videosTable" style="width:100%"></table>
# </div>
# <div class="container mb-15">
# <h2>Tags</h2>
# <p>Aggregate total tag counts on found videos.</p>
# <table class="table table-striped table-hover" id="tagsTable" style="width:100%"></table>
# </div>
# <div class="container mb-15">
# <h2>Geotags</h2>
# <p>
#         Aggregate total geotag counts on found videos.
#         Want to visualize this data in a map?
#         Export this result and import the zip into
#         <a href="https://mattw.io/youtube-geofind" target="_blank">YouTube Geofind</a>!</p>
#
# <table class="table table-striped table-hover" id="geotagsTable" style="width:100%"></table>
# </div>
# <div class="container mb-15">
# <h2>Links</h2>
# <p>
#         Aggregate total link counts in found video descriptions.
#         Be careful visiting what may show up here, by default results will not be hyperlinked for safety.
#     </p>
# <div class="form-check mb-15">
# <input autocomplete="off" class="form-check-input" id="makeHyperlinks" onchange="bulk.toggleLinksColumn(0);bulk.toggleLinksColumn(1)" type="checkbox" value=""/>
# <label class="form-check-label" for="makeHyperlinks">
#             Make them hyperlinks anyways
#         </label>
# </div>
# <table class="table table-striped table-hover" id="linksTable" style="width:100%"></table>
# </div>
# <div class="container mb-15">
# <h2>Upload Frequency</h2>
# <p>
#         Aggregate uploads frequency by hour and day.
#         Transformable to any timezone
#         (<a href="https://upload.wikimedia.org/wikipedia/commons/8/88/World_Time_Zones_Map.png" target="_blank">map</a>)
#         and filterable by year when activity occurred.
#         Guesstimate region using typical sleep/activity patterns, see change in behavior over time,
#         or see typical upload times in your own timezone.
#     </p>
# <div class="row" style="margin: 0 0 1.5em 0">
# <select autocomplete="off" class="form-select" id="offset" style="width:auto;margin-right:10px">
# <option value="-1200">UTC −12:00</option>
# <option value="-1100">UTC −11:00</option>
# <option value="-1000">UTC −10:00</option>
# <option value="-0930">UTC −09:30</option>
# <option value="-0900">UTC −09:00</option>
# <option value="-0800">UTC −08:00</option>
# <option value="-0700">UTC −07:00</option>
# <option value="-0600">UTC −06:00</option>
# <option value="-0500">UTC −05:00</option>
# <option value="-0400">UTC −04:00</option>
# <option value="-0330">UTC −03:30</option>
# <option value="-0300">UTC −03:00</option>
# <option value="-0200">UTC −02:00</option>
# <option value="-0100">UTC −01:00</option>
# <option selected="" value="+0000">UTC ±00:00</option>
# <option value="+0100">UTC +01:00</option>
# <option value="+0200">UTC +02:00</option>
# <option value="+0300">UTC +03:00</option>
# <option value="+0330">UTC +03:30</option>
# <option value="+0400">UTC +04:00</option>
# <option value="+0430">UTC +04:30</option>
# <option value="+0500">UTC +05:00</option>
# <option value="+0530">UTC +05:30</option>
# <option value="+0545">UTC +05:45</option>
# <option value="+0600">UTC +06:00</option>
# <option value="+0630">UTC +06:30</option>
# <option value="+0700">UTC +07:00</option>
# <option value="+0800">UTC +08:00</option>
# <option value="+0845">UTC +08:45</option>
# <option value="+0900">UTC +09:00</option>
# <option value="+0930">UTC +09:30</option>
# <option value="+1000">UTC +10:00</option>
# <option value="+1030">UTC +10:30</option>
# <option value="+1100">UTC +11:00</option>
# <option value="+1200">UTC +12:00</option>
# <option value="+1245">UTC +12:45</option>
# <option value="+1300">UTC +13:00</option>
# <option value="+1345">UTC +13:45</option>
# <option value="+1400">UTC +14:00</option>
# </select>
# <select autocomplete="off" class="form-select" id="year" style="width:auto">
# <option selected="" value="">All years</option>
# </select>
# </div>
# <div id="uploadFrequency"></div>
# </div>
# <div class="container mb-15">
# <h2>Unavailable</h2>
# <p>
#         Videos that are unavailable from channels (created playlists on), playlists, or videos.
#         They are either <a href="https://github.com/mattwright324/youtube-metadata/wiki/Deleted-and-Private-Videos" target="_blank">deleted or made private</a>.
#         Consider searching for user-made playlists to find more unavailable videos.
#     </p>
# <div id="unavailable">
# <div class="input-group mb-3" style="align-items: center;">
# <button class="btn btn-secondary loading disabled" id="checkUnavailable" style="margin-right: 10px" type="button">
# <span>Check Unavailable</span>
# <span class="countdown"></span>
# </button>
# <span>Check Filmot for any archived metadata for unavailable videos.</span>
# </div>
# <div class="progress" style="margin-bottom:5px">
# <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="0" class="progress-bar" id="unavailableProgressBar" role="progressbar" style="">
# <div class="label"></div>
# </div>
# </div>
# <div id="unavailableProgressText" style="width: 100%;text-align: center;">Idle</div>
# <br/>
# </div>
# <label for="unavailable-columns">Select column(s)</label>
# <select hidden="" id="unavailable-columns" multiple="multiple"></select>
# </div>
# <div class="container-fluid mb-15">
# <table class="table table-striped table-hover" id="unavailableTable" style="width:100%"></table>
# </div>
# <div class="container mb-15">
# <h2>Other</h2>
# <p>Other potentially useful aggregate data on found videos.</p>
# <table class="table table-striped table-hover" id="otherTable" style="width:100%"></table>
# </div>
# <div class="ui container" style="padding-top:3%;padding-bottom:3%;color:darkgray;text-align:center">
# <img src="https://developers.google.com/static/youtube/images/developed-with-youtube-sentence-case-light.png" style="width:200px!important">
# <br/>
#     mattwright324 | 2023 | <a href="/">home</a> | <a href="https://github.com/mattwright324">github</a> |
#     <a href="https://github.com/mattwright324/youtube-metadata">youtube-metadata</a>
# <br/>
# <a href="https://github.com/mattwright324/youtube-metadata/blob/master/PRIVACY.md">privacy</a> |
#     <a href="https://github.com/mattwright324/youtube-metadata/blob/master/TERMS.md">terms of use</a> |
#     <a href="/">contact</a>
# </img></div>
# </body>
# </html>

# %%
data = pd.read_csv('The Right Stand - CNN-News18 - Sheet1.csv')
data
# Out:
#                                                   Title      Author   Length  \
# 0     Outsider No More?Why Bharat Ratna for Narasimh...  CNN-News18  21m 33s
# 1     Parliament Debates On White Paper Tabled By Ni...  CNN-News18   32m 2s
# 2     Ballot In Pakistan: Gun Raj In Pakistan Occupi...  CNN-News18  18m 26s
# 3     White Vs Black Paper: Economy Debate Settled? ...  CNN-News18  33m 56s
# 4     UCC Showdown: Uttarakhand's Template For Bhara...  CNN-News18   26m 4s
# ...                                                 ...         ...      ...
# 3154  Centre Likely To Move Triple Talaq Bill In Raj...  CNN-News18   1m 42s
# 3155  Is Your Data Safety Being Compromised For U.S ...  CNN-News18  33m 31s
# 3156  Didi Unveils And Garlands New Vidyasagar Bust ...  CNN-News18  29m 12s
# 3157  Is Congress Losing 'Sabka Vishwas', With Owais...  CNN-News18  44m 21s
# 3158  Is Backing Kashmir Terror, Endgame For "Naya P...  CNN-News18  53m 57s
#
#                  Published   Views Likes Comments Privacy Status  \
# 0     2024-02-09T16:19:09Z  10,068    88       42         public
# 1     2024-02-09T16:14:29Z   1,286     4        1         public
# 2     2024-02-08T17:21:08Z     688     3        0         public
# 3     2024-02-08T17:07:28Z   5,193    47        8         public
# 4     2024-02-07T15:37:35Z   3,898    23        7         public
# ...                    ...     ...   ...      ...            ...
# 3154  2019-07-29T17:30:59Z     719    11        1         public
# 3155  2019-07-29T17:26:45Z     260     4        0         public
# 3156  2019-06-12T02:21:28Z     284     7        1         public
# 3157  2019-06-11T02:02:24Z   1,161    17        5         public
# 3158  2019-02-19T02:06:27Z     977     8        3         public
#
#      Region Restriction Count  Tag Count
# 0                         NaN         14
# 1                         NaN         26
# 2                         NaN         21
# 3                         NaN         27
# 4                         NaN         23
# ...                       ...        ...
# 3154              1 (allowed)         24
# 3155              1 (allowed)         29
# 3156              1 (allowed)         28
# 3157              1 (allowed)         23
# 3158              1 (allowed)         26
#
# [3159 rows x 10 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string
import nltk

nltk.download('punkt')
nltk.download('stopwords')

# Preprocess the text
def preprocess_text(text):
    # Convert text to lowercase
    text = text.lower()
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Tokenize text
    tokens = word_tokenize(text)
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [word for word in tokens if word not in stop_words]
    # Rejoin tokens into a string
    filtered_text = ' '.join(filtered_tokens)
    return filtered_text

data['Processed_Title'] = data['Title'].apply(preprocess_text)

# Vectorize the text
vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(data['Processed_Title'])

# Perform KMeans clustering
# The number of clusters (n_clusters) is set arbitrarily - you might need to adjust this
kmeans = KMeans(n_clusters=7, random_state=42)
kmeans.fit(X)

# Assign the cluster labels to the original data
data['Cluster'] = kmeans.labels_

# Check the size of each cluster
cluster_sizes = data['Cluster'].value_counts()

# Inspect a few titles from each cluster to determine the category
for cluster_num in range(7):
    print(f"Cluster {cluster_num} titles:")
    print(data[data['Cluster'] == cluster_num]['Title'].sample(5))
    print()

# You will need to manually inspect the output and determine what category each cluster represents.
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/meghnadbose/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/meghnadbose/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Cluster 0 titles:
# 1685    Politics Over Cooch Behar Incident | The Right...
# 2942    First Hyderabad, Now Unnao: Another 'Beti' Bet...
# 1400    Choksi Case | Sujay Kantawala Shares His Views...
# 1867    Is Chinnamma's Sacrifice An Advantage For AIAD...
# 3128    Is India's Aura Under PM Modi Brighter Than Ev...
# Name: Title, dtype: object
#
# Cluster 1 titles:
# 1610    India Fights COVID | Time To Call Out Local Le...
# 1996    BJP MP Aparajita Sarangi Says We Need Politica...
# 2727    Time To Recalibrate Military Mindset? | The Ri...
# 3125    Has The Time Arrived For The Global Blacklisti...
# 861     Karnataka News | Praveen Killing Outrage | Tim...
# Name: Title, dtype: object
#
# Cluster 2 titles:
# 1405    Mehul Choksi Scam | Upper hand for India? | La...
# 736     Dr. Vikram Sampath In An Exclusive Chat On His...
# 478     California News | California Gurudwara Shootin...
# 760     Jammu Kashmir News Latest | Naya Kashmir Lates...
# 582     Delhi News | Arrested AAP Ministers Manish Sis...
# Name: Title, dtype: object
#
# Cluster 3 titles:
# 2863    PM Modi Rains Fire On Anti-CAA Forces | The Ri...
# 2928    Cong MP Abhishek Singhvi Takes On Modi Govt Ov...
# 2560    On World Earth Day, Lets Know The Need To Cons...
# 2381    Priyanka Gandhi Bungalow Row: Out Of Lutyens, ...
# 1051    Union Minister Nitin Gadkari EXCLUSIVE | Roadm...
# Name: Title, dtype: object
#
# Cluster 4 titles:
# 855     Amit Shah Drops Bomb On Congress | Ayodhya Ram...
# 49      Ram Mandir Inauguration: Bharat Re-discovering...
# 912     Why No Survey in Gyanvapi Mosque? | The Right ...
# 666     Ram Mandir On Target | Target Beacon Attack Hi...
# 2489    Subramanian Swamy On Ram Mandir: We Must Now B...
# Name: Title, dtype: object
#
# Cluster 5 titles:
# 1289    Pakistan Planning A Big Attack Before August 5...
# 1465    Ashutosh Khajuria, Executive Director, Federal...
# 1437    Robin Campbell, UB40: We Definitely Intend To ...
# 90      The Hidden Hindu Series | Author Akshat Gupta ...
# 405     A Look At India's Meteoric Rise | 9 Years Of P...
# Name: Title, dtype: object
#
# Cluster 6 titles:
# 1513    Narada Investigation A Message To State BJP: T...
# 1575    BJP Was In Self-Congratulatory Mode: Sanjay Jh...
# 163     Israel-Hamas Conflict Day 10 | U.S Stance On I...
# 99      A 4-Day Pause In War: Hostage Deal Done But Is...
# 177     Israel Vs Hamas Today News | Will Israel Confl...
# Name: Title, dtype: object

# %%
# Inspect a few titles from each cluster to determine the category
for cluster_num in range(7):
    print(f"Cluster {cluster_num} titles:")
    titles_sample = data[data['Cluster'] == cluster_num]['Title'].head(10)  # Adjust the number sampled as needed
    for title in titles_sample:
        print(title)
    print("\n")

# You will need to manually inspect the output and determine what category each cluster represents.
# After inspection, create a mapping from cluster number to category name.
cluster_to_category = {
    0: 'Category Name 1',  # Replace with actual category name after inspection
    1: 'Category Name 2',  # Replace with actual category name after inspection
    # ... Continue for each cluster
    6: 'Category Name 7'   # Replace with actual category name after inspection
}

# Apply the mapping to the cluster labels to create a 'Category' column
data['Category'] = data['Cluster'].map(cluster_to_category)

# Check the distribution of the new categorical labels
category_distribution = data['Category'].value_counts()
print(category_distribution)
# Out:
# Cluster 0 titles:
# Do We Need To Learn Lessons On 'Sustainability'? | The Right Stand With Anand Naramsihan | News18
# Kashmir Files Unreported | Vivek Agnihotri's Exclusive Interview On News18 With Anand Narasimhan
# 28% GST On Online Gaming | Ashneer Grover Exclusive Interview With Anand Narasimhan On News18
# Piyush Goyal Speaks To News18's Anand Narasimhan On UCC, Opposition Unity And 2024 Elections
# The Right Stand With Anand Narasimhan, Because India Deserves Better! | The Right Stand On News18
# Punjab News: Who Let Amritpal Singh Escape? | The Right Stand With Anand Narasimhan | News18
# Armaan Malik Interview | Armaan Malik Exclusive With Anand Narasimhan | Times Square | News18
# Punjab News Today | Khalsa Call, Khalistan Intent? | The Right Stand With Anand Narasimhan | News18
# Armaan Malik Interview | Armaan Malik Exclusive | The Right Stand With Anand Narasimhan | News18
# CCP's Duplicity | Wang Yi's "Bhai Bhai" Sentiment For India | The Right Stand With Anand Narasimhan
#
#
# Cluster 1 titles:
# Canada Indira Gandhi Assassination | Brampton Betrayal: Time India Takes A Tougher Stand? | News18
# Pakistan Hounds Minorities | Time For Pak To Pay For Rights Abuses? | Hindu Girl Abducted | News18
# The Right Stand | Time To Outlaw All Extra-Judicial Talaq? | Assertion Of Rights | English News
# Anti India Agenda | Truth About Info War Against India | Prime Time | The Right Stand | English News
# Karnataka News | Praveen Killing Outrage | Time For Strike On Radicals? | Karnataka Killing
# Time To Recognise Hindu Minority? | Hindu Minority Status | The Right Stand | CNN News18
# Hijab Row | Karnataka Hijab Row | Time For Uniform Dress Code? | The Right Perspective | CNN News18
# Democracy Vs Autocracy | Time To Shed One-China, Take Autocracy Head On? | Latest News | CNN News18
# China Galwan Fakery | Xi's Galwan Fakery Exposed | Time Cynics Apologised? | The Right Stand
# The Hindumisia Debate | Time To Acknowledge Hate Against Hindus? | The Right Stand | CNN News18
#
#
# Cluster 2 titles:
# Ballot In Pakistan: Gun Raj In Pakistan Occupied Kashmir? | Pakistan Elections 2024 | English News
# White Vs Black Paper: Economy Debate Settled? | White Paper In Lok Sabha | English News | News18
# UCC Showdown: Uttarakhand's Template For Bharat? | Uttarakhand UCC News | Uniform Civil Code News
# Uniform Civil Code Bill Tabled in Uttarakhand Assembly | Uniform Civil Code | English News | News18
# India's Cybersecurity Challenge: Threats And Strategies | Cyber Terror Threat | English News
# Modi- Macron Bonhomie: Shaping A New Chapter In Ties | Emmanuel Macron In India | English News
# 2024 Mahayudh: Modi Guarantee Vs Wobbly Opposition | Lok Sabha Elections 2024 | English News
# PM Modi Trip To Indian Islands Prompts Maldives Row | Maldives Controversy | English News | News18
# Exclusive: Pujya Puri Shankaracharya Ji On Hindu, Hindutva, And Hindustan | English News | News18
# CAA Notification Soon, Aiding 'Vistapit' Hindus Or 2024 Poll Move? | CAA Latest News | News18
#
#
# Cluster 3 titles:
# GST On Online Gaming | 28% GST On Online Gaming Completely Explained | The Right Stand | News18
# Odisha Train Accident: All The News And Updates So Far On The Right Stand | UPA Vs NDA | News18
# Defence News: Installations A Target For ISIS? Super Intel Scoop On NIA Probe | The Right Stand
# UK Grooming Gangs: Charlie Peters GB News Interview | The Right Stand | United Kingdom | News18
# Decoding Designer Drug Black Cocaine On NCB's Radar | The Right Stand | Bitcoin Trading | News18
# Punjab | Manhunt For Amritpal | Who's Shielding The Fugitive? | Amritpal Singh | The Right Stand
# Rajeev Chandrasekhar Exclusive | Will The E-pharma Crackdown Dissuade Startups? | The Right Stand
# Silicon Valley Bank Collapse | Parliament Session Showdown: Apology Vs JPC? | The Right Stand
# 100 Years Of Sahaja Yoga Founder | The Right Stand | Shri Mataji's Centenary Celebrations | News18
# Does Rahul Gandhi Have A Better Plan For Bharat? | Rahul Gandhi In London | The Right Stand
#
#
# Cluster 4 titles:
# Gyanvapi Verdict News | Gyanvapi Dispute : Is An Amicable Solution Possible ? | Gyanvapi News
# Ram Mandir Special: Mega 'Pran Pratishtha' Rewind | Ayodhya Ram Mandir Pran Pratishtha | News18
# Ayodhya Ram Mandir | Manish Tripathi Exclusive : The Man Who Designed Ram Lalla's Attire | News18
# Mahabharat's Krishna On Ram | Nitish Bharadwaj's Exclusive Interview On Ram | Ram Mandir | News18
# Ram Mandir Ayodhya | PM Modi Unveils Lord Ram Idol | Ram Temple Consecration Ceremony | News18
# Actor And Author Anupam Kher Talks About Ayodhya Ram Mandir's Pran Pratishtha Ceremony | News18
# Ram Lalla Virajman: Special From Ayodhya | Ram Mandir Ayodhya | Ram Temple Inauguration | News18
# Pranam Siya Ram': Team Behind 'Ram Anthem' | Ram Mandir Ayodhya | Ram Temple Inauguration | News18
# Exclusive: Brahmarishi Mohanji Interview | Brahmarishi Mohanji On Ram, Mandir And Bharat | News18
# Hindutva Inclusive In Thought? | Ram Mandir Ayodhya | Ram Temple | Ram Temple Inauguration | News18
#
#
# Cluster 5 titles:
# Parliament Debates On White Paper Tabled By Nirmala Sitharaman | Parliament News Today | News18
# 10 Years UPA VS 10 Years MODI: Will White Paper Settle Debate? | Lok Sabha Elections 2024 | News18
# PM Modi News | PM Modi Predicts 370 Seats For BJP, 400+ For NDA In Lok Sabha Polls | News18
# Grammy Awards | Shankar Mahadevan And Zakir Hussain Won Laurels For Their Band Shakti | News18
# PM Modi Guarantee Vs Oppn 'Cancel, Culture': Lok Sabha 2024, A Forgone Conclusion? | The Right Stand
# Budget 2024 Precursor | Tech In Budget: Player or Destroyer? | Indian Budget 2024 Updates | News18
# Hemant Soren Today | Jharkhand CM Hemant Soren ED News Live | Hemant Soren Delhi House | News18
# 55 Hindu Deity Sculptures Found Inside Gyanvapi Complex: ASI Survey Report On Mosque | News18
# Discussion Over Women & Hindu Tradition | Dayanand Kanya Gurukul | Women's Education In India
# India Maldives Diplomatic Relations | Relations Between India And Maldives After The Controversy
#
#
# Cluster 6 titles:
# Outsider No More?Why Bharat Ratna for Narasimha Rao is Coup by BJP, Has Cong Licking Wounds | News18
# Kerala Court Orders For Death Penalty To 15 PFI Members For Murdering OBC BJP Wing Leader | News18
# BJP News | Congress Vs BJP | Opposition Vs BJP | Will Sabka Saath Topple Bogey Of Caste | News18
# Ladakh BJP MP Jamyang Tsering On Abrogation Of Article 370 | Jammu & Kashmir News | News18
# Telangana Assembly Election Result | BJP MLA Venkata Ramana Reddy Exclusive Interview With News18
# Telangana Politics | BJP Slams KCR's Promise Of IT Park For Minorities | Telangana Election | News18
# A 4-Day Pause In War: Hostage Deal Done But Israel Won't Stop | Israel Vs Hamas Today | English News
# Israel Hamas Conflict | Maayan Zin, Mother Of Girls Abducted By Hamas Shares Her Ordeal | News18
# Israel Palestine Conflict | Allies Changing Tune Against Israel? | Israel Vs Hamas Today | News18
# Israel Vs Hamas | Gaza Hospitals Used By Hamas According To Israel | Israel Vs Palestine | News18
#
#
# Category
# Category Name 1    583
# Category Name 7    184
# Category Name 2     69
# Name: count, dtype: int64

# %%
# Define keywords for each category
category_keywords = {
    'Attacking the Opposition': ['opposition', 'congress', 'aap', 'left', 'critic', 'attack'],
    'Communalism': ['hindu', 'muslim', 'communal', 'hindutva', 'anti-muslim', 'sectarian'],
    'Sports and/or Entertainment': ['cricket', 'hockey', 'football', 'movie', 'entertainment', 'bollywood', 'sports'],
    'Economy': ['economy', 'gdp', 'budget', 'finance', 'economic', 'growth', 'recession'],
    'Foreign Relations': ['china', 'us', 'russia', 'international', 'relations', 'foreign', 'diplomacy', 'trade', 'nepal', 'bangladesh', 'sri lanka'],
    'Pakistan': ['pakistan'],
    'Praising Modi': ['modi', 'narendra', 'bjp', 'prime minister', 'leadership', 'praise'],
    # 'Others' will not have keywords as it is a default category
}

# Function to categorize titles based on keywords
def categorize_title(title):
    title_lower = title.lower()
    for category, keywords in category_keywords.items():
        if any(keyword in title_lower for keyword in keywords):
            return category
    return 'Others'

# Apply the categorization function to each title
data['Category'] = data['Title'].apply(categorize_title)

# Count the number of videos in each category
category_counts = data['Category'].value_counts()

# Print the category counts
print(category_counts)
# Out:
# Category
# Others                         1671
# Foreign Relations               697
# Attacking the Opposition        253
# Praising Modi                   245
# Communalism                     133
# Pakistan                         80
# Economy                          41
# Sports and/or Entertainment      39
# Name: count, dtype: int64
